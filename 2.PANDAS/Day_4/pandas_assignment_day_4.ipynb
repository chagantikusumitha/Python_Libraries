# %% [markdown]
# ##### import the Diamond dataset

# %%
import pandas as pd

# %%
pd.read_csv("diamonds.csv")
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
k = pd.read_csv("diamonds.csv")

# %% [markdown]
# ###### 1. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
### code here
k.shape
# Out:
# (53940, 11)

# %%
k.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %% [markdown]
# ##### 2. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
### code here
k.describe(include = ['object'])
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ###### 3. Write a Pandas program to remove the second column of the diamonds Dataframe. (don't use original dataset)

# %%
### code here
k.drop('carat',axis = 1)
# Out:
#        Unnamed: 0        cut color clarity  depth  table  price     x     y  \
# 0               1      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1               2    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2               3       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3               4    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4               5       Good     J     SI2   63.3   58.0    335  4.34  4.35
# ...           ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935       53936      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936       53937       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937       53938  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938       53939    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53935  3.50
# 53936  3.61
# 53937  3.56
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# ###### 4. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe. (dont use original dataset)

# %%
### code here
k.drop([1,2,3])
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 4      4.35  2.75
# 5      3.96  2.48
# 6      3.98  2.47
# 7      4.11  2.53
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53937 rows x 11 columns]

# %% [markdown]
# ###### 5. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
### code here
k.sort_values(['cut'])
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 3850         3851   1.01       Fair     F     SI2   64.8   55.0   3477  6.37
# 51464       51465   1.20       Fair     G      I1   66.6   57.0   2376  6.57
# 51466       51467   0.90       Fair     G     SI2   65.4   57.0   2376  6.01
# 10237       10238   1.26       Fair     D     SI2   64.5   59.0   4746  6.75
# 10760       10761   1.01       Fair     E     SI1   69.5   55.0   4853  6.00
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 7402         7403   0.33  Very Good     G     VS2   62.8   54.0    579  4.40
# 43101       43102   0.57  Very Good     E     SI2   58.8   57.3   1384  5.42
# 16893       16894   1.00  Very Good     G     VS2   62.2   58.0   6743  6.35
# 16898       16899   1.00  Very Good     D     VS2   59.6   60.0   6745  6.52
# 21164       21165   1.00  Very Good     E    VVS2   61.7   55.0   9324  6.38
#
#           y     z
# 3850   6.26  4.10
# 51464  6.50  4.34
# 51466  5.97  3.98
# 10237  6.71  4.34
# 10760  5.94  4.15
# ...     ...   ...
# 7402   4.42  2.77
# 43101  5.46  3.21
# 16893  6.39  3.96
# 16898  6.57  3.90
# 21164  6.42  3.95
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 6. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
### code here
k.sort_values(['carat'])
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 31593       31594   0.20  Premium     E     VS2   61.1   59.0    367   3.81
# 31597       31598   0.20    Ideal     D     VS2   61.5   57.0    367   3.81
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
# 31595       31596   0.20    Ideal     E     VS2   59.7   55.0    367   3.86
# 31594       31595   0.20  Premium     E     VS2   59.7   62.0    367   3.84
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
#
#            y     z
# 31593   3.78  2.32
# 31597   3.77  2.33
# 31596   3.71  2.33
# 31595   3.84  2.30
# 31594   3.80  2.28
# ...      ...   ...
# 25999   9.94  6.24
# 25998  10.10  6.17
# 27130   9.85  6.43
# 27630  10.16  6.72
# 27415  10.54  6.98
#
# [53940 rows x 11 columns]

# %%
k.sort_values(['carat'],ascending = False)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price      x  \
# 27415       27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74
# 27630       27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23
# 27130       27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00
# 25999       26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14
# ...           ...    ...      ...   ...     ...    ...    ...    ...    ...
# 31592       31593   0.20  Premium     E     VS2   59.0   60.0    367   3.81
# 31591       31592   0.20  Premium     E     VS2   59.8   62.0    367   3.79
# 31601       31602   0.20  Premium     D     VS2   61.7   60.0    367   3.77
# 14             15   0.20  Premium     E     SI2   60.2   62.0    345   3.79
# 31596       31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73
#
#            y     z
# 27415  10.54  6.98
# 27630  10.16  6.72
# 27130   9.85  6.43
# 25999   9.94  6.24
# 25998  10.10  6.17
# ...      ...   ...
# 31592   3.78  2.24
# 31591   3.77  2.26
# 31601   3.72  2.31
# 14      3.75  2.27
# 31596   3.71  2.33
#
# [53940 rows x 11 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
#### code here
k[k.loc[:,'carat'] >= 0.3]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 16             17   0.30      Ideal     I     SI2   62.0   54.0    348  4.31
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 4      4.35  2.75
# 10     4.28  2.73
# 13     4.37  2.71
# 15     4.42  2.68
# 16     4.34  2.68
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [52341 rows x 11 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
### code here 
k[(k.loc[:,'x'] > 5) & (k.loc[:,'y'] > 5) & (k.loc[:,'z'] > 5) ]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 11778       11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34
# 13002       13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74
# 13118       13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01
# 13562       13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59
# 13757       13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
# 49905       49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01
#
#            y      z
# 11778   7.28   5.12
# 13002   7.70   5.36
# 13118   7.95   5.23
# 13562   7.56   5.04
# 13757   8.02   5.36
# ...      ...    ...
# 27748   7.97   5.04
# 27749   8.47   5.16
# 48410   5.15  31.80
# 49189  31.80   5.12
# 49905   5.04   5.06
#
# [1457 rows x 11 columns]

# %% [markdown]
# ###### 9. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
### code here
k.mean()
# Out:
# C:\Users\KUSUMI~1\AppData\Local\Temp/ipykernel_14960/3156420665.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   k.mean()
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# x                 5.731157
# y                 5.734526
# z                 3.538734
# dtype: float64

# %% [markdown]
# ###### 10. Write a Pandas program to calculate the mean of price for each cut  and find maximum top 3 of diamonds DataFrame.

# %%
#### code here
k
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# 2      4.07  2.31
# 3      4.23  2.63
# 4      4.35  2.75
# ...     ...   ...
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64
#
# [53940 rows x 11 columns]

# %%
k.groupby(['cut'])['price'].mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
k.sort_values(['price'],ascending = False)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
# 27746       27747   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20
# 27745       27746   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
#
#           y     z
# 27749  8.47  5.16
# 27748  7.97  5.04
# 27747  7.41  4.56
# 27746  8.13  5.11
# 27745  8.00  5.01
# ...     ...   ...
# 4      4.35  2.75
# 3      4.23  2.63
# 2      4.07  2.31
# 1      3.84  2.31
# 0      3.98  2.43
#
# [53940 rows x 11 columns]

# %%
p = k.sort_values(['price'],ascending = False)

# %%
p.iloc[0:3,:]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27747       27748   1.51      Ideal     G      IF   61.7   55.0  18806  7.37
#
#           y     z
# 27749  8.47  5.16
# 27748  7.97  5.04
# 27747  7.41  4.56

# %% [markdown]
# ##### 11. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
### code here
k.groupby(["cut"])["price"].agg(["min","max","count"])
# Out:
#            min    max  count
# cut
# Fair       337  18574   1610
# Good       327  18788   4906
# Ideal      326  18806  21551
# Premium    326  18823  13791
# Very Good  336  18818  12082

# %% [markdown]
# ###### 12. Write a Pandas program to display and count the unique values in cut series of diamonds DataFrame.

# %%
### code here
k["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ######13.  Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
### code here
k.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# ###### 14. Write a Pandas program to calculate the multiply of x, y and z for each cut of diamonds DataFrame.

# %%
### code here
[k.x*k.y*k.z]
# Out:
# [0         38.202030
#  1         34.505856
#  2         38.076885
#  3         46.724580
#  4         51.917250
#              ...
#  53935    115.920000
#  53936    118.110175
#  53937    114.449728
#  53938    140.766120
#  53939    124.568444
#  Length: 53940, dtype: float64]

# %% [markdown]
# ##### 15. Write a Pandas program to read rows 0 through 2 (inclusive), columns ‘color’ and ‘price’ of diamonds DataFrame.

# %%
## code here
k.loc[0:2,["color","price"]]
# Out:
#   color  price
# 0     E    326
# 1     E    326
# 2     E    327

# %% [markdown]
# ###### 16. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
### code here
k.iloc[[0,1],[0,3]]
# Out:
#    Unnamed: 0 color
# 0           1     E
# 1           2     E

# %% [markdown]
# ##### 17. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
### code here
k.sample(n = 3)
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 20531       20532   1.46    Ideal     H     SI1   62.4   55.0   8855  7.26
# 41655       41656   0.58    Ideal     F     SI2   62.0   57.0   1239  5.32
# 18963       18964   1.29  Premium     H     VS2   60.7   61.0   7802  7.10
#
#           y     z
# 20531  7.22  4.52
# 41655  5.35  3.31
# 18963  7.01  4.28

# %% [markdown]
# ###### 18. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
### code here
k.sample(frac = 0.75)
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 106           107   0.80    Premium     G     SI1   63.0   59.0   2760  5.90
# 53580       53581   0.74  Very Good     F     SI1   61.7   55.0   2698  5.83
# 42297       42298   0.32      Ideal     H     VS2   62.0   55.0    505  4.38
# 41773       41774   0.55    Premium     H     SI2   62.4   56.0   1246  5.23
# 44615       44616   0.53    Premium     G     VS2   60.7   59.0   1607  5.24
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 23143       23144   1.71    Premium     H     VS1   58.1   62.0  11161  8.02
# 30149       30150   0.32  Very Good     E     SI1   63.4   55.0    720  4.36
# 24680       24681   1.50  Very Good     F     VS2   63.9   57.0  13037  7.16
# 31962       31963   0.43    Premium     H      I1   62.0   59.0    452  4.78
# 5082         5083   0.90  Very Good     G     SI1   63.3   56.0   3752  6.08
#
#           y     z
# 106    5.81  3.69
# 53580  5.87  3.61
# 42297  4.40  2.72
# 41773  5.20  3.25
# 44615  5.18  3.16
# ...     ...   ...
# 23143  7.84  4.61
# 30149  4.35  2.76
# 24680  7.23  4.60
# 31962  4.83  2.98
# 5082   6.11  3.86
#
# [40455 rows x 11 columns]

# %%
h = k.sample(frac = 0.75)

# %%
h.count()
# Out:
# Unnamed: 0    40455
# carat         40455
# cut           40455
# color         40455
# clarity       40455
# depth         40455
# table         40455
# price         40455
# x             40455
# y             40455
# z             40455
# dtype: int64

# %%
k.loc[~k.index.isin(h.index), :]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 21             22   0.23  Very Good     E     VS2   63.8   55.0    352  3.85
# 28             29   0.23  Very Good     D     VS2   60.5   61.0    357  3.96
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53925       53926   0.79      Ideal     I     SI1   61.6   56.0   2756  5.95
# 53929       53930   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76
# 53933       53934   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69
# 53934       53935   0.72    Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
#
#           y     z
# 1      3.84  2.31
# 8      3.78  2.49
# 9      4.05  2.39
# 21     3.92  2.48
# 28     3.97  2.40
# ...     ...   ...
# 53925  5.97  3.67
# 53929  5.73  3.53
# 53933  5.72  3.49
# 53934  5.73  3.58
# 53935  5.76  3.50
#
# [13485 rows x 11 columns]

# %%
s= k.loc[~k.index.isin(h.index), :]

# %%
s.count()
# Out:
# Unnamed: 0    13485
# carat         13485
# cut           13485
# color         13485
# clarity       13485
# depth         13485
# table         13485
# price         13485
# x             13485
# y             13485
# z             13485
# dtype: int64

# %% [markdown]
# ###### 19. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
#### code here
k.color.duplicated().sum()
# Out:
# 53933

# %%
k.clarity.duplicated().sum()
# Out:
# 53932

# %% [markdown]
# ###### 20. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
#### code here

# %%
k.duplicated().sum()
# Out:
# 0
